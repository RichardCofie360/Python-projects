# %%
import  pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
df=pd.read_csv('Proffessional_survey.csv',encoding='latin1')

# %%
df
# Out:
#                     Unique ID      Email Date Taken (America/New_York)  \
# 0    62a33b3db4da29969c62df3d  anonymous                     6/10/2022
# 1    62a33ba1bae91e4b8b82e35c  anonymous                     6/10/2022
# 2    62a33c2cbc6861bf3176bec1  anonymous                     6/10/2022
# 3    62a33c8624a26260273822f9  anonymous                     6/10/2022
# 4    62a33c91f3072dd892621e03  anonymous                     6/10/2022
# ..                        ...        ...                           ...
# 625  62b525563f28f20328aeee5c  anonymous                     6/23/2022
# 626  62b5a3e29bc428d5345f6e89  anonymous                     6/24/2022
# 627  62b71083f31287f32e189026  anonymous                     6/25/2022
# 628  62b795033b026e423f287ecd  anonymous                     6/25/2022
# 629  62b89039377223ff07b80fb5  anonymous                     6/26/2022
#
#     Time Taken (America/New_York)  Browser  OS  City  Country  Referrer  \
# ...

# %%
df.columns
# Out:
# Index(['Unique ID', 'Email', 'Date Taken (America/New_York)',
#        'Time Taken (America/New_York)', 'Browser', 'OS', 'City', 'Country',
#        'Referrer', 'Time Spent',
#        'Q1 - Which Title Best Fits your Current Role?',
#        'Q2 - Did you switch careers into Data?',
#        'Q3 - Current Yearly Salary (in USD)',
#        'Q4 - What Industry do you work in?',
#        'Q5 - Favorite Programming Language',
#        'Q6 - How Happy are you in your Current Position with the following? (Salary)',
#        'Q6 - How Happy are you in your Current Position with the following? (Work/Life Balance)',
#        'Q6 - How Happy are you in your Current Position with the following? (Coworkers)',
#        'Q6 - How Happy are you in your Current Position with the following? (Management)',
#        'Q6 - How Happy are you in your Current Position with the following? (Upward Mobility)',
# ...

# %%
drop_columns=['Unique ID', 'Email', 'Date Taken (America/New_York)',
       'Time Taken (America/New_York)',
       'Referrer', 'Time Spent']
df=df.drop(columns=drop_columns,axis=1)

# %%
df.columns
# Out:
# Index(['Browser', 'OS', 'City', 'Country',
#        'Q1 - Which Title Best Fits your Current Role?',
#        'Q2 - Did you switch careers into Data?',
#        'Q3 - Current Yearly Salary (in USD)',
#        'Q4 - What Industry do you work in?',
#        'Q5 - Favorite Programming Language',
#        'Q6 - How Happy are you in your Current Position with the following? (Salary)',
#        'Q6 - How Happy are you in your Current Position with the following? (Work/Life Balance)',
#        'Q6 - How Happy are you in your Current Position with the following? (Coworkers)',
#        'Q6 - How Happy are you in your Current Position with the following? (Management)',
#        'Q6 - How Happy are you in your Current Position with the following? (Upward Mobility)',
#        'Q6 - How Happy are you in your Current Position with the following? (Learning New Things)',
#        'Q7 - How difficult was it for you to break into Data?',
# ...

# %%
replace_columns={'Q1 - Which Title Best Fits your Current Role?':'role',
                'Q2 - Did you switch careers into Data?':'switch_careers',
                'Q3 - Current Yearly Salary (in USD)':'salary',
                'Q4 - What Industry do you work in?':'industry',
                'Q5 - Favorite Programming Language':'programming_language',
                'Q6 - How Happy are you in your Current Position with the following? (Salary)':'happiness_position',
                'Q6 - How Happy are you in your Current Position with the following? (Work/Life Balance)':'happiness_work/life_balace',
                'Q6 - How Happy are you in your Current Position with the following? (Coworkers)':'hapinnes_coworkres',
                 'Q6 - How Happy are you in your Current Position with the following? (Management)':'happiness_management',
                 'Q6 - How Happy are you in your Current Position with the following? (Upward Mobility)':'happiness_upward_mobility',
                'Q6 - How Happy are you in your Current Position with the following? (Learning New Things)':'happiness_learning', 
                 'Q7 - How difficult was it for you to break into Data?':'difficulty', 
                 'Q8 - If you were to look for a new job today, what would be the most important thing to you?':'important_new_job',
                 'Q9 - Male/Female?':'sex', 
                 'Q10 - Current Age':'age',
                 'Q11 - Which Country do you live in?':'country',
                 'Q12 - Highest Level of Education':'education',
                 'Q13 - Ethnicity':'ethnicity'
                  }
df=df.rename(columns=replace_columns)

# %%
df
# Out:
#      Browser  OS  City  Country                                          role  \
# 0        NaN NaN   NaN      NaN                                  Data Analyst
# 1        NaN NaN   NaN      NaN                                  Data Analyst
# 2        NaN NaN   NaN      NaN                                 Data Engineer
# 3        NaN NaN   NaN      NaN  Other (Please Specify):Analytics Consultant
# 4        NaN NaN   NaN      NaN                                  Data Analyst
# ..       ...  ..   ...      ...                                           ...
# 625      NaN NaN   NaN      NaN                                  Data Analyst
# 626      NaN NaN   NaN      NaN  Other (Please Specify):Data Scientist Intern
# 627      NaN NaN   NaN      NaN                          Student/Looking/None
# 628      NaN NaN   NaN      NaN                                 Data Engineer
# 629      NaN NaN   NaN      NaN                                  Data Analyst
#
# ...

# %%
df.isna().sum()
# Out:
# Browser                       630
# OS                            630
# City                          630
# Country                       630
# role                            0
# switch_careers                  0
# salary                          0
# industry                        0
# programming_language            0
# happiness_position              7
# happiness_work/life_balace     10
# hapinnes_coworkres             11
# happiness_management           12
# happiness_upward_mobility      13
# happiness_learning              5
# difficulty                      0
# important_new_job               0
# sex                             0
# age                             0
# country                         0
# education                      52
# ethnicity                       0
# dtype: int64

# %%
drop_columns=['Browser', 'OS', 'City',
       'Country'
       ]
df=df.drop(columns=drop_columns,axis=1)

# %%
df.isna().sum()
# Out:
# role                           0
# switch_careers                 0
# salary                         0
# industry                       0
# programming_language           0
# happiness_position             7
# happiness_work/life_balace    10
# hapinnes_coworkres            11
# happiness_management          12
# happiness_upward_mobility     13
# happiness_learning             5
# difficulty                     0
# important_new_job              0
# sex                            0
# age                            0
# country                        0
# education                     52
# ethnicity                      0
# dtype: int64

# %%
df['role'].unique()
# Out:
# array(['Data Analyst', 'Data Engineer',
#        'Other (Please Specify):Analytics Consultant ', 'Data Scientist',
#        'Student/Looking/None', 'Other (Please Specify):FP&A Analyst',
#        'Other (Please Specify):BI Developer ',
#        'Other (Please Specify):Manager, Business Intelligence Develop',
#        'Other (Please Specify):Business Analyst ',
#        'Other (Please Specify):Business Analyst',
#        'Other (Please Specify):Business Intelligence Consultant',
#        'Other (Please Specify):Sr. Supply Chain Analyst ',
#        'Other (Please Specify):Business analyst ',
#        'Other (Please Specify):Director of Data Analytics',
#        'Other (Please Specify):Learning Management Specialist',
#        'Other (Please Specify):Research Analyst',
#        'Other (Please Specify):Insights analyst',
#        'Other (Please Specify):Does a social media analyst count?',
#        'Other (Please Specify):Educator',
# ...

# %%
df['role'] = df['role'].str.replace('Other (Please Specify):', ' ')
# Out:
# C:\Users\Richard\AppData\Local\Temp\ipykernel_520\3706359592.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['role'] = df['role'].str.replace('Other (Please Specify):', ' ')

# %%
df['role'].unique()
# Out:
# array(['Data Analyst', 'Data Engineer',
#        'Other (Please Specify):Analytics Consultant ', 'Data Scientist',
#        'Student/Looking/None', 'Other (Please Specify):FP&A Analyst',
#        'Other (Please Specify):BI Developer ',
#        'Other (Please Specify):Manager, Business Intelligence Develop',
#        'Other (Please Specify):Business Analyst ',
#        'Other (Please Specify):Business Analyst',
#        'Other (Please Specify):Business Intelligence Consultant',
#        'Other (Please Specify):Sr. Supply Chain Analyst ',
#        'Other (Please Specify):Business analyst ',
#        'Other (Please Specify):Director of Data Analytics',
#        'Other (Please Specify):Learning Management Specialist',
#        'Other (Please Specify):Research Analyst',
#        'Other (Please Specify):Insights analyst',
#        'Other (Please Specify):Does a social media analyst count?',
#        'Other (Please Specify):Educator',
# ...

# %%
df['role'] = df['role'].str.replace(r'Other \(Please Specify\):', '')
# Out:
# C:\Users\Richard\AppData\Local\Temp\ipykernel_520\1187835134.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['role'] = df['role'].str.replace(r'Other \(Please Specify\):', '')

# %%
df['role'].unique()
# Out:
# array(['Data Analyst', 'Data Engineer', 'Analytics Consultant ',
#        'Data Scientist', 'Student/Looking/None', 'FP&A Analyst',
#        'BI Developer ', 'Manager, Business Intelligence Develop',
#        'Business Analyst ', 'Business Analyst',
#        'Business Intelligence Consultant', 'Sr. Supply Chain Analyst ',
#        'Business analyst ', 'Director of Data Analytics',
#        'Learning Management Specialist', 'Research Analyst',
#        'Insights analyst', 'Does a social media analyst count?',
#        'Educator', 'Business Intelligence Engineer',
#        'Research Associate ', 'Analytics Manager',
#        'Manager of a team of Data Analysts', 'Analyst',
#        'Analytics Engineer', 'Analyst Primary Market Intelligence',
#        'software engineer', 'Data Architect', 'Data Integrity',
#        'Database Developer', 'Financial Analyst', 'Database Manager',
#        'Software Developer ', 'Tableau admin', 'Other (Please Specify)',
# ...

# %%
role_to_replace={'Manager, Business Intelligence Develop':'Business Intelligence Developer',
                 'BI Developer ':'BI Developer',
                 'Business Analyst ':'Business Analyst',
                 'Business analyst ':'Business Analyst',
                 'Director of Data Analytics':'Data Analyst',
                 'Insights analyst':'Insights Analyst',
                 'Analytics Manager':'Data Analyst',
                 'Manager of a team of Data Analysts':'Data Analyst',
                 'Analyst':'Data Analyst',
                 'software engineer':'Software Engineer',
                 'Jr. Data Scientist':'Data Scientist',
                 'Business Analys':'Business Analyst',
                 'Junior Software Engineer':'Software Engineer',
                 'Researchers ':'Researchers',
                  'Senior Business Analyst':'Business Analyst',
                 'Student working as a data analyst intern ':'Student',
                 'DBA':'Data Analyst',
                 'Technical consulta':'Technical consultant',
                 'Software Engineer, AI ':'Software Engineer',
                 'Data Scientist Intern':'Data Scientist'
                 }
df['role']=df['role'].replace(role_to_replace)

# %%
df['role'].unique()
# Out:
# array(['Data Analyst', 'Data Engineer', 'Analytics Consultant ',
#        'Data Scientist', 'Student/Looking/None', 'FP&A Analyst',
#        'BI Developer', 'Business Intelligence Developer',
#        'Business Analyst', 'Business Intelligence Consultant',
#        'Sr. Supply Chain Analyst ', 'Learning Management Specialist',
#        'Research Analyst', 'Insights Analyst',
#        'Does a social media analyst count?', 'Educator',
#        'Business Intelligence Engineer', 'Research Associate ',
#        'Analytics Engineer', 'Analyst Primary Market Intelligence',
#        'Software Engineer', 'Data Architect', 'Data Integrity',
#        'Database Developer', 'Financial Analyst', 'Database Manager',
#        'Software Developer ', 'Tableau admin', 'Other (Please Specify)',
#        'Reporting Adm', 'Billing analyst',
#        'I work with data tools and can create simple dashboards but I am not a data scientist',
#        'Marketing Data Specialist',
# ...

# %%
df['switch_careers'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['industry'].unique()
# Out:
# array(['Healthcare', 'Finance', 'Other (Please Specify):Clean Energy',
#        'Other (Please Specify):Coworking space ',
#        'Other (Please Specify):Retail', 'Telecommunication',
#        'Other (Please Specify):Logistics',
#        'Other (Please Specify):Igaming', 'Tech', 'Education',
#        'Construction', 'Other (Please Specify):Aviation',
#        'Other (Please Specify):Insurance',
#        'Other (Please Specify):Energy',
#        'Other (Please Specify):Oil and gas', 'Other (Please Specify)',
#        'Other (Please Specify):Automotive',
#        'Other (Please Specify):Automotive ',
#        'Other (Please Specify):Utili',
#        'Other (Please Specify):Not working yet',
#        'Other (Please Specify):Manufa',
#        'Other (Please Specify):Manufacturing (Chemicals)',
#        'Other (Please Specify):Currently studying . Previously worked in Power Generation',
# ...

# %%
df['industry'] = df['industry'].str.replace(r'Other \(Please Specify\):', '')
# Out:
# C:\Users\Richard\AppData\Local\Temp\ipykernel_520\2998223601.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['industry'] = df['industry'].str.replace(r'Other \(Please Specify\):', '')

# %%
df['industry'].unique()
# Out:
# array(['Healthcare', 'Finance', 'Clean Energy', 'Coworking space ',
#        'Retail', 'Telecommunication', 'Logistics', 'Igaming', 'Tech',
#        'Education', 'Construction', 'Aviation', 'Insurance', 'Energy',
#        'Oil and gas', 'Other (Please Specify)', 'Automotive',
#        'Automotive ', 'Utili', 'Not working yet', 'Manufa',
#        'Manufacturing (Chemicals)',
#        'Currently studying . Previously worked in Power Generation',
#        'Not working at the moment, but previously I have been into Education industry',
#        'Third Party Logistics ', 'Food & Beverage ', 'Marketing',
#        'Advertising', 'Staffing and Recruting ', 'Biotech', 'Consulting',
#        'Consumer Elec', 'Semiconductor manufacturing',
#        'Supply Chain - warehousing, transpiration and ', 'Distribution',
#        'Customer Service', 'Ecom', 'Consulti', 'State Government',
#        'Culture', 'Government', 'Manufacturing', 'Cons', 'Wholesale',
# ...

# %%
industry_to_replace={'Clean Energy':'Energy',
                     'Automotive ':'Automotive',
                     'Manufacturing (Chemicals)':'Manufacturing',
                     'Manufa':'Manufacturing',
                     'Currently studying . Previously worked in Power Generation':'Not working yet',
                     'Not working at the moment, but previously I have been into Education industry':'Not working yet',
                     'Third Party Logistics ':'Logistics',
                     'Advertising':'Marketing',
                     'Semiconductor manufacturing':'Manufacturing',
                      'Supply Chain - warehousing, transpiration and ':'Logistics',
                     'Distribution':'Logistics',
                     'Customer Service':'Marketing',
                      'Ecom':'Marketing',
                     'Consulti':'Consulting',
                     'State Government':'Government',
                     'Cons':'Construction',
                     'Wholesale':'Logistics',
                     'Energy ':'Energy',
                     'Government programs':'Government',
                      'Supply Chain':'Logistics',
                     'Aerospace':'Aviation',
                     'Foodservice Franchising':'Beverage and foods',
                     'Government ':'Government',
                     'Entertainment ':'Entertainment',
                     'Energy (oil and gas)':'Energy',
                     'Chemical Manufacturing':'Manufacturing',
                     'Customer service ':'Marketing',
                     ' Manufacturering ':'Manufacturing',
                     'fashion/online store':'Marketing',
                      'Marketing ': 'Marketing',
                     'Hospitality ':'Hospitality',
                     'Poultry':'Agriculture',
                     'Medical industry ':'Healthcare',
                      'Warehouse':'Logistics',
                     'Non profit Animal Welfare':'Agriculture',
                     'Insurance ':'Insurance',
                     'E-commerce':'Marketing',
                     'IT':'Tech',
                     'Media & advertising ':'Marketing',
                     'sports':'Sports',
                     'Sports/Marketing':'Marketing',
                     'last mile delivery logistics':'Logistics',
                     'Arrosp':'Aviation',
                     'i`m currently student':'Student',
                     'I am a student':'Student',
                     'Manuf':'Manufacturing',
                     'Automobile Industry':'Automotive',
                     'Fmcg':'Marketing',
                     'NGO - Legislation ':'Logistics',
                     'Culinary':'Marketing',
                     'I am student.':'Student', 
                     'Home maker ':'Real Estate',
                     'Digital Mar':'Tech',
                     'Unemployed, trying to switch career':'Not working yet',
                     'Ecommerce':'Marketing',
                     'Logistics and warehousing':'Logistics',
                     'Looking for job':'Not working yet',
                     'Food and bece':'Beverage and foods',
                     'Research (non-clincial)':'Researcher',
                     'Gover':'Government',
                     'Foodservice':'Beverage and foods',
                     'Data insights company':'Tech',
                     'Not currently working':'Not working yet',
                     'Food and Beverages':'Beverage and foods',
                     'Government Administration':'Government',
                     'Outsourcing ':'Outsourcing',
                     'General contractor':'Construction',
                     'Police / Emergency Services':'Law Enforcement',
                     'Consumer retail':'Marketing',
                     'Air transpo':'Aviation',
                     'Distribution ':'Logistics',
                     'None for now':'Not working yet',
                     'Retails':'Marketing',
                     'Direct Marketing':'Marketing',
                     'FMCG':'Marketing',
                     'Digital Marketing ':'Marketing',
                     'Retail ':'Marketing',
                     'Automobile (cars)':'Automotive',
                     'Beverage and foods':'Beverage and foods',
                     'Space & Defense':'Defense',
                     'Utili':'Utilities',
                     'Utilities ':'Utilities',
                     'Audit Firm':'Professional Services',
                     'Outsourcing':'Professional Services',
                     'Food & Beverage ':'Beverage and foods',
                     'Public transport':'Transportation',
                     'Retail':'Marketing',
                     'Staffing and Recruting ':'Professional Services',
                     'Oil and gas':'Energy',
                     'Utilities ':'Utilities',
                      'I am student. ':'Student',
                     'hospitality':'Hospitality',
                     'none':'None',
                     'Consumer Elec':'Electronics',
                     'Avia':'Aviation',
                     'Market research':'Researcher',
                     'Nonprofit':'Nonprofit',
                     'Igaming':'Tech',
                     'Reta':'Marketing'
                     }
df['industry']=df['industry'].replace(industry_to_replace)

# %%
df['industry'].unique()
# Out:
# array(['Healthcare', 'Finance', 'Energy', 'Coworking space ', 'Marketing',
#        'Telecommunication', 'Logistics', 'Tech', 'Education',
#        'Construction', 'Aviation', 'Insurance', 'Other (Please Specify)',
#        'Automotive', 'Utilities', 'Not working yet', 'Manufacturing',
#        'Beverage and foods', 'Professional Services', 'Biotech',
#        'Consulting', 'Electronics', 'Government', 'Culture',
#        'Entertainment', 'Researcher', 'Hospitality', 'Real Estate',
#        'Agriculture', 'Renewable Resources', 'Sports', 'Student',
#        'Management', 'None', 'Social work ', 'Legal', 'Nonprofit',
#        'Law Enforcement', 'Demography and Social Statistics ',
#        'Customer support ', 'Cosmetics ', 'Maritime', 'Transportation',
#        'Urbanism', 'State', 'Sensors', 'Defense', 'Outsourcing',
#        'Cobsukting', 'Workforce ', 'Home and living',
#        'Non Profit Organization', 'Homelessness', 'Taking bootcamp',
# ...

# %%
df['programming_language'].unique()
# Out:
# array(['Python', 'R', 'Other:SQL',
#        'Other:Mostly use sql but that\x92s not programming language..',
#        'Other:Qlik sense script', 'Other:sql', 'Other:Power bi',
#        'JavaScript',
#        "Other:If SQL is categorised as a programming language then I will definitely say SQL. Since I am still learning, I can't give a definite answer in relation to the abover mentioned but for the sake of choosing I will say R then followed by python",
#        'C/C++', 'Other:I don\x92t know any', 'Other:Sql',
#        'Other:Dont require', 'Other',
#        'Other:Knowledge of Excel and SQL yet',
#        "Other:I don't use programming in my role", 'Other:Excel/SQL',
#        'Other:unknown', 'Other:SQL Postgres ', 'Other:DAX', 'Other:Vba',
#        'Other:Stata', 'Other:Excel',
#        'Other:I currently do not work with programming languages yet',
#        'Other:Altery', 'Other:None', 'Other:c#', 'Other:SQL ',
#        'Other:Just started learning ',
# ...

# %%
df['programming_language'] = df['programming_language'].str.replace(r'Other:', '')

# %%
df['programming_language'].unique()
# Out:
# array(['Python', 'R', 'SQL',
#        'Mostly use sql but that\x92s not programming language..',
#        'Qlik sense script', 'sql', 'Power bi', 'JavaScript',
#        "If SQL is categorised as a programming language then I will definitely say SQL. Since I am still learning, I can't give a definite answer in relation to the abover mentioned but for the sake of choosing I will say R then followed by python",
#        'C/C++', 'I don\x92t know any', 'Sql', 'Dont require', 'Other',
#        'Knowledge of Excel and SQL yet',
#        "I don't use programming in my role", 'Excel/SQL', 'unknown',
#        'SQL Postgres ', 'DAX', 'Vba', 'Stata', 'Excel',
#        'I currently do not work with programming languages yet', 'Altery',
#        'None', 'c#', 'SQL ', 'Just started learning ',
#        'i mean, i mostly work in SQL and its variants?', 'Java', 'SAS',
#        'NA', 'Mainly use Excel',
#        'SQL because that is all I know really well so far. ', 'VBA',
# ...

# %%
programming_language_to_replace={'Mostly use sql but that\x92s not programming language..':'SQL',
                                 'sql':'SQL',
                                  "If SQL is categorised as a programming language then I will definitely say SQL. Since I am still learning, I can't give a definite answer in relation to the abover mentioned but for the sake of choosing I will say R then followed by python":'SQL',
                                 'I don\x92t know any':'None',
                                 'Sql':'SQL','Dont require':'None',
                                 'Knowledge of Excel and SQL yet':'Excel and SQL',
                                 "I don't use programming in my role":'None',
                                 'Excel/SQL':'Excel and SQL',
                                 'unknown':'None',
                                 'SQL Postgres ':'SQL',
                                 'I currently do not work with programming languages yet':'None',
                                 'Altery':'Alteryx',
                                 'SQL ':'SQL',
                                 'Just started learning ':'None',
                                  'i mean, i mostly work in SQL and its variants?':'SQL',
                                 'Java':'JavaScript',
                                 'NA':'None',
                                 'Mainly use Excel':'Excel',
                                 'SQL because that is all I know really well so far. ':'SQL',
                                 'Vba':'VBA',
                                 'Sql &  plsql':'SQL',
                                 'SAS SQL':'SAS and SQL',
                                 'None at the moment':'None',
                                 'excel':'Excel',
                                 'I do analysis and create presentations based on datasets provided by others':'None',
                                  }
df['programming_language']=df['programming_language'].replace(programming_language_to_replace)

# %%
df['programming_language'].unique()
# Out:
# array(['Python', 'R', 'SQL', 'Qlik sense script', 'Power bi',
#        'JavaScript', 'C/C++', 'None', 'Other', 'Excel and SQL', 'DAX',
#        'VBA', 'Stata', 'Excel', 'Alteryx', 'c#', 'SAS', 'MATLAB', 'Php',
#        'SAS and SQL'], dtype=object)

# %%
df['happiness_position'].unique()
# Out:
# array([ 9.,  1.,  0., 10.,  2.,  4.,  3.,  7.,  5.,  6.,  8., nan])

# %%
df['happiness_work/life_balace'].unique()
# Out:
# array([ 9.,  2.,  8.,  6.,  4.,  3.,  5.,  0., 10.,  1.,  7., nan])

# %%
df['hapinnes_coworkres'].unique()
# Out:
# array([ 7.,  5.,  4.,  3.,  6.,  8., 10.,  9.,  2.,  1.,  0., nan])

# %%
df['happiness_management'].unique()
# Out:
# array([ 5.,  2., 10.,  4.,  3.,  6.,  8.,  9.,  7.,  1.,  0., nan])

# %%
df['happiness_upward_mobility'].unique()
# Out:
# array([ 5.,  1.,  7.,  0.,  3.,  6.,  8.,  4.,  2., 10.,  9., nan])

# %%
df['happiness_learning'].unique()
# Out:
# array([ 7.,  3., 10.,  1.,  2.,  5.,  9.,  4.,  8.,  0.,  6., nan])

# %%
df['difficulty'].unique()
# Out:
# array(['Very Difficult', 'Easy', 'Very Easy', 'Difficult',
#        'Neither easy nor difficult'], dtype=object)

# %%
df['important_new_job'].unique()
# Out:
# array(['Remote Work', 'Good Work/Life Balance', 'Better Salary',
#        'Good Culture', 'Other (Please Specify):Responsibilities',
#        'Other (Please Specify):Development',
#        'Other (Please Specify):Strong organizational data strategy, high-performing team',
#        'Other (Please Specify):I would say a combination of good work/life balance with a better pay and the exposure to a workplace that supposed growth',
#        'Other (Please Specify):Currently very happy with where I am.',
#        'Other (Please Specify):My passion is to become a Data analyst ',
#        'Other (Please Specify):Different job title, either product owner or consulting',
#        'Other (Please Specify):Opportunity for advancement ',
#        'Other (Please Specify):Want to move from Australia to Canada, so position in desired country ',
#        'Other (Please Specify):All of the options are important to me when looking for a new job',
# ...

# %%
df['important_new_job'] = df['important_new_job'].str.replace(r'Other \(Please Specify\):', '')
# Out:
# C:\Users\Richard\AppData\Local\Temp\ipykernel_520\658753477.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['important_new_job'] = df['important_new_job'].str.replace(r'Other \(Please Specify\):', '')

# %%
df['important_new_job'].unique()
# Out:
# array(['Remote Work', 'Good Work/Life Balance', 'Better Salary',
#        'Good Culture', 'Responsibilities', 'Development',
#        'Strong organizational data strategy, high-performing team',
#        'I would say a combination of good work/life balance with a better pay and the exposure to a workplace that supposed growth',
#        'Currently very happy with where I am.',
#        'My passion is to become a Data analyst ',
#        'Different job title, either product owner or consulting',
#        'Opportunity for advancement ',
#        'Want to move from Australia to Canada, so position in desired country ',
#        'All of the options are important to me when looking for a new job',
#        'Both Good work / life Balance and Good Culture',
#        'an environment that encourages growth like where I work currently and better salary ',
#        'Learning possibilities', 'Opportunities for growth ',
# ...

# %%
important_new_job_to_replace={'I would say a combination of good work/life balance with a better pay and the exposure to a workplace that supposed growth':'Good Work/Life Balance & Better Salary & high-performing team',
                              'Strong organizational data strategy, high-performing team':'Strong organizational data strategy & high-performing team',
                              'Both Good work / life Balance and Good Culture':'Good Work/Life Balance and Good Culture',
                              'an environment that encourages growth like where I work currently and better salary ':'Opportunities for growth & Better Salary',
                              'Opportunities for growth ':'Opportunities for growth',
                              'Different job title, either product owner or consulting':'Different job title',
                               'I just started and I don\'t like programming so much, so I would search for a more "impactiful" role. Meaning: being able to take decisions that steer the business.':'Different job title',
                              'Good opportunities in projects and learnjng':'Opportunity for advancement',
                              'Opportunity for advancement ':'Opportunity for advancement',
                              'Mix of better salary, good work/life balance, remote work and good culture':'Better Salary, Good work/Life balance, Remote Work and Good Culture',
                              'Learning opportunity':'Learning possibilities',
                              'Learning New Things':'Learning possibilities',
                              'Salary and expo':'Better Salary',
                              'Learning new skills':'Learning possibilities',
                              'Opportunity to learn':'Learning possibilities',
                              'Better work & remote salary':'Better work & Remote Salary',
                              'Remote too':'Remote Work',
                              'Career Advancedment':'Opportunity for advancement',
                              'All of the options are important to me when looking for a new job':'All of the above',
                               'Good work  life Balance and Good Culture': 'Good work/life Balance and Good Culture',
                              'Opportunities for growth':'Opportunity for advancement'
                                }
df['important_new_job']=df['important_new_job'].replace(important_new_job_to_replace)

# %%
df['important_new_job'].unique()
# Out:
# array(['Remote Work', 'Good Work/Life Balance', 'Better Salary',
#        'Good Culture', 'Responsibilities', 'Development',
#        'Strong organizational data strategy & high-performing team',
#        'Good Work/Life Balance & Better Salary & high-performing team',
#        'Currently very happy with where I am.',
#        'My passion is to become a Data analyst ', 'Different job title',
#        'Opportunity for advancement',
#        'Want to move from Australia to Canada, so position in desired country ',
#        'All of the above', 'Good Work/Life Balance and Good Culture',
#        'Opportunities for growth & Better Salary',
#        'Learning possibilities', 'Opportunities for growth',
#        'Projects I\x92m interested in',
#        'Mentorship from leading Data Analyst', 'Intresting work',
#        'Better Salary, Good work/Life balance, Remote Work and Good Culture',
#        'In office work', 'Challenging / exciting problems',
# ...

# %%
df['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['age'].unique()
# Out:
# array([26, 36, 23, 35, 44, 33, 24, 28, 37, 32, 34, 30, 31, 29, 22, 43, 25,
#        42, 40, 41, 38, 21, 27, 39, 51, 55, 45, 52, 50, 56, 20, 47, 54, 19,
#        92, 60, 53, 18, 48, 58, 66], dtype=int64)

# %%
df['country'].unique()
# Out:
# array(['United States', 'Canada', 'Other (Please Specify):Nigeria',
#        'Other (Please Specify):Republic democratic of Congo ',
#        'Other (Please Specify)', 'Other (Please Specify):Serbia',
#        'Other (Please Specify):Argentina', 'United Kingdom',
#        'Other (Please Specify):Niger', 'Other (Please Specify):Kenya',
#        'Other (Please Specify):Azerbaijan',
#        'Other (Please Specify):Sudan', 'India',
#        'Other (Please Specify):Japan', 'Other (Please Specify):Greece',
#        'Other (Please Specify):Perú ', 'Other (Please Specify):Australia',
#        'Other (Please Specify):Spain', 'Other (Please Specify):Kenya ',
#        'Other (Please Specify):Barbados',
#        'Other (Please Specify):South Africa',
#        'Other (Please Specify):Colombia',
#        'Other (Please Specify):Germany',
#        'Other (Please Specify):Bulgaria', 'Other (Please Specify):Turkey',
#        'Other (Please Specify):France', 'Other (Please Specify):Thailand',
# ...

# %%
df['country'] = df['country'].str.replace(r'Other \(Please Specify\):', '')
# Out:
# C:\Users\Richard\AppData\Local\Temp\ipykernel_520\649604405.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['country'] = df['country'].str.replace(r'Other \(Please Specify\):', '')

# %%
df['country'].unique()
# Out:
# array(['United States', 'Canada', 'Nigeria',
#        'Republic democratic of Congo ', 'Other (Please Specify)',
#        'Serbia', 'Argentina', 'United Kingdom', 'Niger', 'Kenya',
#        'Azerbaijan', 'Sudan', 'India', 'Japan', 'Greece', 'Perú ',
#        'Australia', 'Spain', 'Kenya ', 'Barbados', 'South Africa',
#        'Colombia', 'Germany', 'Bulgaria', 'Turkey', 'France', 'Thailand',
#        'Netherlands', 'Denmark', 'Brazil', 'Mexico', 'Chile',
#        'Costa Rica', 'Vietnam', 'Nigeria ', 'Portugal', 'turkey', 'Egypt',
#        'Pakistan', 'Ireland ', 'Poland', 'Mozambique', 'Egypt ', 'Israel',
#        'Singapore', 'Belgium', 'UAE', ' Somalia', 'Kosovo', 'Iraq',
#        'Romania', 'Peru', 'Philippines', 'Malaysia', 'nigeria', 'Ghana',
#        'Portugsl', 'Macedonia', 'Irel', 'Morocco', 'Costa Rica ', 'Iran',
#        'South Africa ', 'Bangladesh ', 'Ire', 'Antigua ', 'Venezuela',
#        'Brazik', 'South Korea', 'Panama', 'indonesia', 'Angola',
# ...

# %%
country_to_replace={'Kenya ':'Kenya',
                    'Nigeria ':'Nigeria',
                    'turkey':'Turkey',
                    'Egypt ':'Egypt',
                    'Perú ':'Peru',
                    'nigeria':'Nigeria',
                    'Portugsl':'Portugal',
                    'Costa Rica ':'Costa Rica',
                    'Irel':'Ireland',
                    'South Africa ':'South Africa',
                    'indonesia':'Indonesia',
                    'Brazik':'Brazil',
                    'Africa (Nigeria)':'Nigeria',
                    'ghana':'Ghana',
                    'UAE':'United Arab Emirates',
                    'United Arab Emirates ':'United Arab Emirates',
                    'TUNISIA':'Tunisia',
                    'Saudi Arabia ':'Saudi Arabia',
                    'Austr':'Australia',
                    'Argentine':'Argentina',
                    'Kenua':'Kenya',
                    'Argentina ':'Argentina',
                     'Ireland ': 'Ireland',
                    'Leba':'Lybia',
                    'Morocco ':'Morocco',
                    'Ire':'Ireland'
                   }
df['country']=df['country'].replace(country_to_replace)

# %%
df['country'].unique()
# Out:
# array(['United States', 'Canada', 'Nigeria',
#        'Republic democratic of Congo ', 'Other (Please Specify)',
#        'Serbia', 'Argentina', 'United Kingdom', 'Niger', 'Kenya',
#        'Azerbaijan', 'Sudan', 'India', 'Japan', 'Greece', 'Peru',
#        'Australia', 'Spain', 'Barbados', 'South Africa', 'Colombia',
#        'Germany', 'Bulgaria', 'Turkey', 'France', 'Thailand',
#        'Netherlands', 'Denmark', 'Brazil', 'Mexico', 'Chile',
#        'Costa Rica', 'Vietnam', 'Portugal', 'Egypt', 'Pakistan',
#        'Ireland', 'Poland', 'Mozambique', 'Israel', 'Singapore',
#        'Belgium', 'United Arab Emirates', ' Somalia', 'Kosovo', 'Iraq',
#        'Romania', 'Philippines', 'Malaysia', 'Ghana', 'Macedonia', 'Iran',
#        'Morocco', 'Bangladesh ', 'Antigua ', 'Venezuela', 'South Korea',
#        'Panama', 'Indonesia', 'Angola', 'Fin', 'Lybia', 'Saudi Arabia',
#        'Zambia', 'Uruguay', 'Hong Kong', 'Tunisia', 'Sri lanka',
# ...

# %%
df['education'].unique()
# Out:
# array([nan, 'High School', 'Bachelors', 'Masters', 'Associates', 'PhD'],
#       dtype=object)

# %%
df['ethnicity'].unique()
# Out:
# array(['White or Caucasian', 'Asian or Asian American',
#        'Black or African American', 'Hispanic or Latino',
#        'Other (Please Specify):Latino with Italian roots',
#        'Other (Please Specify):African',
#        'Other (Please Specify):South Asian',
#        'Other (Please Specify):Indian',
#        'Other (Please Specify):Kenyan African ',
#        'Other (Please Specify):Black African, Zimbabwean Citizen',
#        'Other (Please Specify):Human',
#        "Other (Please Specify):Race isn't a thing",
#        'Other (Please Specify):Middleeas',
#        'Other (Please Specify):Mixed ( Caucasian / African-American )',
#        'Other (Please Specify):Half Asian half African ',
#        'Other (Please Specify):Brown',
#        'Other (Please Specify):Prefer not to ans',
#        'Other (Please Specify):N/A', 'Other (Please Specify):African ',
#        'Other (Please Specify)', 'Other (Please Specify):Kurdish',
#        'Native Hawaiian or other Pacific Islander',
# ...

# %%
df['ethnicity'] = df['ethnicity'].str.replace(r'Other \(Please Specify\):', '')
# Out:
# C:\Users\Richard\AppData\Local\Temp\ipykernel_520\1759641943.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ethnicity'] = df['ethnicity'].str.replace(r'Other \(Please Specify\):', '')

# %%
df['ethnicity'].unique()
# Out:
# array(['White or Caucasian', 'Asian or Asian American',
#        'Black or African American', 'Hispanic or Latino',
#        'Latino with Italian roots', 'African', 'South Asian', 'Indian',
#        'Kenyan African ', 'Black African, Zimbabwean Citizen', 'Human',
#        "Race isn't a thing", 'Middleeas',
#        'Mixed ( Caucasian / African-American )',
#        'Half Asian half African ', 'Brown', 'Prefer not to ans', 'N/A',
#        'African ', 'Other (Please Specify)', 'Kurdish',
#        'Native Hawaiian or other Pacific Islander', 'Bangladeshi',
#        'Pakistani', 'Russian', 'Egyp', 'Half black and half white', '7',
#        'Bla', 'Moroccan', 'Indian ', 'Arab ', 'Sudanese African ',
#        'American Indian or Alaska Native',
#        'Bi-racial people should be able to check 2 options in 2022. ',
#        'Melayu', 'Dravidian', 'arab', 'Asian', 'South Indian ', 'Greek',
#        'Nigeria', 'Arab', 'Arabian (from Maghreb)', 'Malay'], dtype=object)

# %%
ethnicity_to_replace={'Kenyan African ':'African',
                      'Black African, Zimbabwean Citizen':'African',
                      'Middleeas':'Middleeast',
                      "Race isn't a thing":'N/A',
                      'Human':'N/A',
                      'African ':'African',
                      'Egyp':'African',
                      'Half black and half white':'Mixed ( Caucasian / African-American )',
                      '7':'N/A',
                      'Bla':'African',
                      'Sudanese African ':'African',
                      'Moroccan':'African',
                      'Nigeria':'African',
                      'Prefer not to ans':'N/A',
                       }
df['ethnicity']=df['ethnicity'].replace(ethnicity_to_replace)

# %%
df['ethnicity'].unique()
# Out:
# array(['White or Caucasian', 'Asian or Asian American',
#        'Black or African American', 'Hispanic or Latino',
#        'Latino with Italian roots', 'African', 'South Asian', 'Indian',
#        'N/A', 'Middleeast', 'Mixed ( Caucasian / African-American )',
#        'Half Asian half African ', 'Brown', 'Other (Please Specify)',
#        'Kurdish', 'Native Hawaiian or other Pacific Islander',
#        'Bangladeshi', 'Pakistani', 'Russian', 'Indian ', 'Arab ',
#        'American Indian or Alaska Native',
#        'Bi-racial people should be able to check 2 options in 2022. ',
#        'Melayu', 'Dravidian', 'arab', 'Asian', 'South Indian ', 'Greek',
#        'Arab', 'Arabian (from Maghreb)', 'Malay'], dtype=object)

# %%
df
# Out:
#                       role switch_careers     salary       industry  \
# 0             Data Analyst            Yes  106k-125k     Healthcare
# 1             Data Analyst             No    41k-65k        Finance
# 2            Data Engineer             No      0-40k         Energy
# 3    Analytics Consultant             Yes  150k-225k        Finance
# 4             Data Analyst            Yes    41k-65k     Healthcare
# ..                     ...            ...        ...            ...
# 625           Data Analyst            Yes  125k-150k      Marketing
# 626         Data Scientist             No      0-40k  Manufacturing
# 627   Student/Looking/None            Yes      0-40k           Tech
# 628          Data Engineer             No      0-40k           Tech
# 629           Data Analyst             No    41k-65k     Automotive
#
#     programming_language  happiness_position  happiness_work/life_balace  \
# 0                 Python                 9.0                         9.0
# ...

# %%
df['salary'].unique()
# Out:
# array(['106k-125k', '41k-65k', '0-40k', '150k-225k', '125k-150k',
#        '86k-105k', '66k-85k', '225k+'], dtype=object)

# %%
# what roles had the highest salary
role_salary=df[['role','salary']].groupby('role')
role_salary

# %%
df.to_csv('clean_professional_survey.csv',index=False)
